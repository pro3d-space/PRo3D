# %%
#r "nuget: Newtonsoft.Json"
#r "nuget: Chiron, 6.0.0"
#r "nuget: Aardvark.Base"

# %%
#load "../../PRo3D.Base/GeoJSON.fs"

open PRo3D.Base.GeoJSON
# Out:
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(1,1): error CS7021: Cannot declare namespace in script code
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(1,21): error CS1514: { expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(6,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(7,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(8,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(10,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(12,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(14,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(15,6): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(17,8): error CS1002: ; expected
#
# d:\_REPOS\PRo3D\src\PRo3D.Base\GeoJSON.fs(17,8): error CS0116: A namespace cannot directly contain members such as fields, methods or statements
#
# ...

# %%
let geoJsonPoint = """
{
  "type": "Feature",
  "geometry": {
    "type": "Point",
    "coordinates": [10.0, 20.0, 30.0]
  },
  "properties": {
    "elevation": "42.0",
    "name": "TestPoint"
  }
}
"""
# Out:
# (13,4): error CS1002: ; expected
